# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\kgunturu\\Desktop\\Python\\nyc_weather.csv")

# %%
weather_data={
    'day':['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/5/2017'],
    'temperature':[32,35,28,24,32,31],
    'wndspeed': [6,7,2,7,4,2],
    'event': ['Rain','Sunny','Snow','Snow','Rain','Sunny']
}

# %%
df=pd.DataFrame(weather_data)

# %%
df
# Out:
#         day  temperature  wndspeed  event
# 0  1/1/2017           32         6   Rain
# 1  1/2/2017           35         7  Sunny
# 2  1/3/2017           28         2   Snow
# 3  1/4/2017           24         7   Snow
# 4  1/5/2017           32         4   Rain
# 5  1/5/2017           31         2  Sunny

# %%
df.shape
# Out:
# (6, 4)

# %%
rows, columns = df.shape

# %%
rows
# Out:
# 6

# %%
columns
# Out:
# 4

# %%
df.head()
# Out:
#         day  temperature  wndspeed  event
# 0  1/1/2017           32         6   Rain
# 1  1/2/2017           35         7  Sunny
# 2  1/3/2017           28         2   Snow
# 3  1/4/2017           24         7   Snow
# 4  1/5/2017           32         4   Rain

# %%
df.head(2)
# Out:
#         day  temperature  wndspeed  event
# 0  1/1/2017           32         6   Rain
# 1  1/2/2017           35         7  Sunny

# %%
df.tail()
# Out:
#         day  temperature  wndspeed  event
# 1  1/2/2017           35         7  Sunny
# 2  1/3/2017           28         2   Snow
# 3  1/4/2017           24         7   Snow
# 4  1/5/2017           32         4   Rain
# 5  1/5/2017           31         2  Sunny

# %%
df.tail(1)
# Out:
#         day  temperature  wndspeed  event
# 5  1/5/2017           31         2  Sunny

# %%
df[2:5]
# Out:
#         day  temperature  wndspeed event
# 2  1/3/2017           28         2  Snow
# 3  1/4/2017           24         7  Snow
# 4  1/5/2017           32         4  Rain

# %%
df[:]
# Out:
#         day  temperature  wndspeed  event
# 0  1/1/2017           32         6   Rain
# 1  1/2/2017           35         7  Sunny
# 2  1/3/2017           28         2   Snow
# 3  1/4/2017           24         7   Snow
# 4  1/5/2017           32         4   Rain
# 5  1/5/2017           31         2  Sunny

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'wndspeed', 'event'], dtype='object')

# %%
df.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/5/2017
# Name: day, dtype: object

# %%
df.event #df['event']
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4     Rain
# 5    Sunny
# Name: event, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['event'])
# Out:
# pandas.core.series.Series

# %%
df[['event','day']]
# Out:
#    event       day
# 0   Rain  1/1/2017
# 1  Sunny  1/2/2017
# 2   Snow  1/3/2017
# 3   Snow  1/4/2017
# 4   Rain  1/5/2017
# 5  Sunny  1/5/2017

# %%
df['temperature'].min()
# Out:
# 24

# %%
df['temperature'].max()
# Out:
# 35

# %%
df['temperature'].std()
# Out:
# 3.8297084310253524

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         day  temperature  wndspeed  event
# 0  1/1/2017           32         6   Rain
# 1  1/2/2017           35         7  Sunny
# 2  1/3/2017           28         2   Snow
# 3  1/4/2017           24         7   Snow
# 4  1/5/2017           32         4   Rain
# 5  1/5/2017           31         2  Sunny>

# %%
df.describe()
# Out:
#        temperature  wndspeed
# count     6.000000  6.000000
# mean     30.333333  4.666667
# std       3.829708  2.338090
# min      24.000000  2.000000
# 25%      28.750000  2.500000
# 50%      31.500000  5.000000
# 75%      32.000000  6.750000
# max      35.000000  7.000000

# %%
df[df.temperature>=32]
# Out:
#         day  temperature  wndspeed  event
# 0  1/1/2017           32         6   Rain
# 1  1/2/2017           35         7  Sunny
# 4  1/5/2017           32         4   Rain

# %%
df[df.temperature==df.temperature.max()]
# Out:
#         day  temperature  wndspeed  event
# 1  1/2/2017           35         7  Sunny

# %%
df.wndspeed==2
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# Name: wndspeed, dtype: bool

# %%
df[df.event==df.event=='Rain']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-76d99b93c82a> in <module>
# ----> 1 df[df.event==df.event=='Rain']
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1440     @final
#    1441     def __nonzero__(self):
# -> 1442         raise ValueError(
#    1443             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1444             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df.event=='Rain'
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# Name: event, dtype: bool

# %%
df[df.event=='Rain']
# Out:
#         day  temperature  wndspeed event
# 0  1/1/2017           32         6  Rain
# 4  1/5/2017           32         4  Rain

# %%
df[df.temperature==df['temperature'].max()] # use this syntax when there are any spaces in the column
# Out:
#         day  temperature  wndspeed  event
# 1  1/2/2017           35         7  Sunny

# %%
df[df.temperature==df['temperature'].min()]
# Out:
#         day  temperature  wndspeed event
# 3  1/4/2017           24         7  Snow

# %%
df['temperature']==24
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# Name: temperature, dtype: bool

# %%
df.temperature==24
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# Name: temperature, dtype: bool

# %%
df[df.temperature==24]
# Out:
#         day  temperature  wndspeed event
# 3  1/4/2017           24         7  Snow

# %%
df[df.temperature==df.temperature.max()]
# Out:
#         day  temperature  wndspeed  event
# 1  1/2/2017           35         7  Sunny

# %%
df[['day','temperature']]
# Out:
#         day  temperature
# 0  1/1/2017           32
# 1  1/2/2017           35
# 2  1/3/2017           28
# 3  1/4/2017           24
# 4  1/5/2017           32
# 5  1/5/2017           31

# %%
df[['day','temperature']][df.temperature==df['temperature'].max()]
# Out:
#         day  temperature
# 1  1/2/2017           35

# %%
df
# Out:
#         day  temperature  wndspeed  event
# 0  1/1/2017           32         6   Rain
# 1  1/2/2017           35         7  Sunny
# 2  1/3/2017           28         2   Snow
# 3  1/4/2017           24         7   Snow
# 4  1/5/2017           32         4   Rain
# 5  1/5/2017           31         2  Sunny

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.set_index('day', inplace=True)

# %%
df
# Out:
#           temperature  wndspeed  event
# day
# 1/1/2017           32         6   Rain
# 1/2/2017           35         7  Sunny
# 1/3/2017           28         2   Snow
# 1/4/2017           24         7   Snow
# 1/5/2017           32         4   Rain
# 1/5/2017           31         2  Sunny

# %%
df.loc['1/4/2017']
# Out:
# temperature      24
# wndspeed          7
# event          Snow
# Name: 1/4/2017, dtype: object

# %%
df.reset_index()
# Out:
#         day  temperature  wndspeed  event
# 0  1/1/2017           32         6   Rain
# 1  1/2/2017           35         7  Sunny
# 2  1/3/2017           28         2   Snow
# 3  1/4/2017           24         7   Snow
# 4  1/5/2017           32         4   Rain
# 5  1/5/2017           31         2  Sunny

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#         day  temperature  wndspeed  event
# 0  1/1/2017           32         6   Rain
# 1  1/2/2017           35         7  Sunny
# 2  1/3/2017           28         2   Snow
# 3  1/4/2017           24         7   Snow
# 4  1/5/2017           32         4   Rain
# 5  1/5/2017           31         2  Sunny

# %%
df.describe()
# Out:
#        temperature  wndspeed
# count     6.000000  6.000000
# mean     30.333333  4.666667
# std       3.829708  2.338090
# min      24.000000  2.000000
# 25%      28.750000  2.500000
# 50%      31.500000  5.000000
# 75%      32.000000  6.750000
# max      35.000000  7.000000
