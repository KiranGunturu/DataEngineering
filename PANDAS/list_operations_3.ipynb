# %%
ListA=[1,2,3,4]

# %%
ListB=ListA

# %%
print(ListA)
# Out:
# [1, 2, 3, 4]

# %%
print(ListB)
# Out:
# [1, 2, 3, 4]

# %%
ListB[0]='X'

# %%
print(ListB)
# Out:
# ['X', 2, 3, 4]

# %%
print(ListA)
# Out:
# ['X', 2, 3, 4]

# %%
ListA[0]='A'

# %%
print(ListA)
# Out:
# ['A', 2, 3, 4]

# %%
print(ListB)
# Out:
# ['A', 2, 3, 4]

# %%
812371
