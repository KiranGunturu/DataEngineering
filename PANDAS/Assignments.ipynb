# %%
myList=[10,20,30,40,True,False,8.10]
myList.append([50])

# %%
myList
# Out:
# [10, 20, 30, 40, True, False, 8.1, [50]]

# %%
myList.reverse()

# %%
myList
# Out:
# [[50], 8.1, False, True, 40, 30, 20, 10]

# %%
myList[]
# Out:
# [10]

# %%
myList=[10,20,30,40,True,False,8.10]
myList1.extend([50,60]) 
[10, 20, 30, 40, True, False, 8.1, 50, 60]
myList1=[10,20,30,40,True,False,8.10]
myList
myList.append([50,60]) 
myList1.extend([50,60]) 

myList
myList1
# Out:
# [10, 20, 30, 40, True, False, 8.1, 50, 60]

# %%
myList=[10,20,30,40,True,False,8.10]

# %%
myList
# Out:
# [10, 20, 30, 40, True, False, 8.1]

# %%
myList[::-1]
# Out:
# [8.1, False, True, 40, 30, 20, 10]

# %%
import numpy as np

# %%
a=np.arange(2,11,1)

# %%
np.reshape(a,(3,3))
# Out:
# array([[ 2,  3,  4],
#        [ 5,  6,  7],
#        [ 8,  9, 10]])

# %%
y=[]
a=int(input("Enter Size of Array"))
for i in range(a):
    x=int(input("element"))
    y.append(x)
print("original array is :",y)
z=np.array(y,dtype=float)
print("converted array is:",z)
# Out:
# Enter Size of Array5
# element1
# element2
# element3
# element4
# element5
# original array is : [1, 2, 3, 4, 5]
# converted array is: [1. 2. 3. 4. 5.]

# %%
x=[10,20,30]
x=np.append(x,[[40,50,60],[70,80,90]])

# %%
x
# Out:
# array([10, 20, 30, 40, 50, 60, 70, 80, 90])

# %%
np.reshape(x,(3,3))
# Out:
# array([[10, 20, 30],
#        [40, 50, 60],
#        [70, 80, 90]])

# %%
x=np.array([10,20,30])
y=np.array([40,50,60])
z=np.add(x,y)
z
# Out:
# array([50, 70, 90])

# %%
a=np.arange(10,91,10)

# %%
a
# Out:
# array([10, 20, 30, 40, 50, 60, 70, 80, 90])

# %%
b=np.reshape(a,(3,3))

# %%
b
# Out:
# array([[10, 20, 30],
#        [40, 50, 60],
#        [70, 80, 90]])

# %%
b[0,:]
# Out:
# array([10, 20, 30])

# %%
b[1,1]
# Out:
# 50

# %%
def add1(c,d):
    z=np.add(c,d)
    return z
c=np.array([1,2,3])
d=np.array([4,5,6])

print(add1(c,d))
# Out:
# [5 7 9]
