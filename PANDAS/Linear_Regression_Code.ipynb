# %% [markdown]
# # Problem Statement

# %% [markdown]
# In this Linear Machine Learning model, We'll work on cars dataset which consists of all hardware specifications of differents cars.
#
# we are going to predict Miles per Gallon(MPG) of the cars with some indipendent variables from the dataset.

# %% [markdown]
# # Importing Libraries

# %%
#  Importing libraries for exploratory Data Analysis

import pandas as pd
import numpy as np

#  Importing libraries for Data Visualization

import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
#  importing Data 
cars = pd.read_csv("cars.csv")

# %%
cars.head()
# Out:
#               Model    MPG  Cylinder   Disp     HP  ...   Qsec  VS  AM  Gear  Carb
# 0          Mazda RX4  21.0         6  160.0  110.0  ...  16.46   0   1     4     4
# 1      Mazda RX4 Wag  21.0         6  160.0  110.0  ...  17.02   0   1     4     4
# 2         Datsun 710  22.8         4  108.0   93.0  ...  18.61   1   1     4     1
# 3     Hornet 4 Drive  21.4         6  258.0  110.0  ...  19.44   1   0     3     1
# 4  Hornet Sportabout  18.7         8  360.0  175.0  ...  17.02   0   0     3     2
#
# [5 rows x 12 columns]

# %%
#checking data set shape
print(cars.shape)
# Out:
# (32, 12)

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Model     32 non-null     object
#  1   MPG       32 non-null     float64
#  2   Cylinder  32 non-null     int64
#  3   Disp      29 non-null     float64
#  4   HP        29 non-null     float64
#  5   Drat      32 non-null     float64
#  6   Wt        32 non-null     float64
#  7   Qsec      32 non-null     float64
#  8   VS        32 non-null     int64
#  9   AM        32 non-null     int64
#  10  Gear      32 non-null     int64
#  11  Carb      32 non-null     int64
# dtypes: float64(6), int64(5), object(1)
# memory usage: 3.1+ KB

# %%
cars.describe()
# Out:
#              MPG   Cylinder        Disp  ...         AM       Gear     Carb
# count  32.000000  32.000000   29.000000  ...  32.000000  32.000000  32.0000
# mean   20.090625   6.187500  229.789655  ...   0.406250   3.687500   2.8125
# std     6.026948   1.785922  129.299092  ...   0.498991   0.737804   1.6152
# min    10.400000   4.000000   71.100000  ...   0.000000   3.000000   1.0000
# 25%    15.425000   4.000000  120.300000  ...   0.000000   3.000000   2.0000
# 50%    19.200000   6.000000  167.600000  ...   0.000000   4.000000   2.0000
# 75%    22.800000   8.000000  350.000000  ...   1.000000   4.000000   4.0000
# max    33.900000   8.000000  472.000000  ...   1.000000   5.000000   8.0000
#
# [8 rows x 11 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
#checking for null values in data set
cars.isnull().sum()
# Out:
# Model       0
# MPG         0
# Cylinder    0
# Disp        3
# HP          3
# Drat        0
# Wt          0
# Qsec        0
# VS          0
# AM          0
# Gear        0
# Carb        0
# dtype: int64

# %%
cars.describe()
# Out:
#              MPG   Cylinder        Disp          HP       Drat         Wt  \
# count  32.000000  32.000000   29.000000   29.000000  32.000000  32.000000
# mean   20.090625   6.187500  229.789655  145.206897   3.596563   3.217250
# std     6.026948   1.785922  129.299092   71.434975   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.300000   95.000000   3.080000   2.581250
# 50%    19.200000   6.000000  167.600000  113.000000   3.695000   3.325000
# 75%    22.800000   8.000000  350.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             Qsec         VS         AM       Gear     Carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# 25%    16.892500   0.000000   0.000000   3.000000   2.0000
# 50%    17.710000   0.000000   0.000000   4.000000   2.0000
# 75%    18.900000   1.000000   1.000000   4.000000   4.0000
# max    22.900000   1.000000   1.000000   5.000000   8.0000

# %%
#  replacing the  null values with mean value
cars = cars.fillna(cars.mean())

# %%
cars.isnull().sum()
# Out:
# Model       0
# MPG         0
# Cylinder    0
# Disp        0
# HP          0
# Drat        0
# Wt          0
# Qsec        0
# VS          0
# AM          0
# Gear        0
# Carb        0
# dtype: int64

# %%
cars.boxplot()

# %% [markdown]
# ### Box plot to analyse outiers

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cars.boxplot(figsize=(15,10))
plt.show()

# %%
cars.plot(kind='box', subplots=True, layout=(5,4) ,fontsize=12, figsize=(20,20))
plt.show()

# %%
cars.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-57a1fb87fd0a> in <module>()
# ----> 1 cars.columns
#
# NameError: name 'cars' is not defined

# %%
del cars['Model']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Model'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-6e23e0d2c001> in <module>()
# ----> 1 del cars['Model']
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __delitem__(self, key)
#    3711             # there was no match, this call should raise the appropriate
#    3712             # exception:
# -> 3713             loc = self.axes[-1].get_loc(key)
#    3714             self._mgr.idelete(loc)
#    3715
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'Model'

# %%
cars.head()
# Out:
#     MPG  Cylinder   Disp     HP  Drat     Wt   Qsec  VS  AM  Gear  Carb
# 0  21.0         6  160.0  110.0  3.90  2.620  16.46   0   1     4     4
# 1  21.0         6  160.0  110.0  3.90  2.875  17.02   0   1     4     4
# 2  22.8         4  108.0   93.0  3.85  2.320  18.61   1   1     4     1
# 3  21.4         6  258.0  110.0  3.08  3.215  19.44   1   0     3     1
# 4  18.7         8  360.0  175.0  3.15  3.440  17.02   0   0     3     2

# %%
cars.isnull().sum()
# Out:
# MPG         0
# Cylinder    0
# Disp        0
# HP          0
# Drat        0
# Wt          0
# Qsec        0
# VS          0
# AM          0
# Gear        0
# Carb        0
# dtype: int64

# %%
Q1=cars.quantile(.25)
Q3=cars.quantile(.75)
IQR= Q3-Q1
minimumCap= Q1-1.5*IQR
maximumCap= Q3+1.5*IQR
cars.columns.size
for x in cars.iloc[:,:].columns :
    cars[x].replace(cars[[cars[x]]<minimumCap[x]],np.nan,inplace=True)
    cars[x].replace(cars[[cars[x]]>maximumCap[x]],np.nan,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-10a23c8fc0e6> in <module>()
#       6 cars.columns.size
#       7 for x in cars.iloc[:,:].columns :
# ----> 8     cars[x].replace(cars[[cars[x]]<minimumCap[x]],np.nan,inplace=True)
#       9     cars[x].replace(cars[[cars[x]]>maximumCap[x]],np.nan,inplace=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2895         # Do we have a (boolean) 1d indexer?
#    2896         if com.is_bool_indexer(key):
# -> 2897             return self._getitem_bool_array(key)
#    2898
#    2899         # We are left with two options: a single key, and a collection of keys,
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    2942         elif len(key) != len(self.index):
#    2943             raise ValueError(
# -> 2944                 f"Item wrong length {len(key)} instead of {len(self.index)}."
#    2945             )
#    2946
#
# ValueError: Item wrong length 1 instead of 32.

# %%
cars.corr()
# Out:
#                MPG  Cylinder      Disp  ...        AM      Gear      Carb
# MPG       1.000000 -0.852162 -0.844253  ...  0.599832  0.480285 -0.550925
# Cylinder -0.852162  1.000000  0.883549  ... -0.522607 -0.492687  0.526988
# Disp     -0.844253  0.883549  1.000000  ... -0.589928 -0.530916  0.407567
# HP       -0.764345  0.806028  0.781902  ... -0.227285 -0.091671  0.761158
# Drat      0.681172 -0.699938 -0.682647  ...  0.712711  0.699610 -0.090790
# Wt       -0.867659  0.782496  0.882466  ... -0.692495 -0.583287  0.427606
# Qsec      0.418684 -0.591242 -0.428585  ... -0.229861 -0.212682 -0.656249
# VS        0.664039 -0.810812 -0.677328  ...  0.168345  0.206023 -0.569607
# AM        0.599832 -0.522607 -0.589928  ...  1.000000  0.794059  0.057534
# Gear      0.480285 -0.492687 -0.530916  ...  0.794059  1.000000  0.274073
# Carb     -0.550925  0.526988  0.407567  ...  0.057534  0.274073  1.000000
#
# [11 rows x 11 columns]

# %%
sb.heatmap(cars.corr())

# %%
cars.corr()
#HFM | Consolidation Standards | FCCS | HFM Standards | FCCS Stan
# Out:
#                MPG  Cylinder      Disp        HP      Drat        Wt  \
# MPG       1.000000 -0.852162 -0.844253 -0.764345  0.681172 -0.867659
# Cylinder -0.852162  1.000000  0.883549  0.806028 -0.699938  0.782496
# Disp     -0.844253  0.883549  1.000000  0.781902 -0.682647  0.882466
# HP       -0.764345  0.806028  0.781902  1.000000 -0.414259  0.649502
# Drat      0.681172 -0.699938 -0.682647 -0.414259  1.000000 -0.712441
# Wt       -0.867659  0.782496  0.882466  0.649502 -0.712441  1.000000
# Qsec      0.418684 -0.591242 -0.428585 -0.711671  0.091205 -0.174716
# VS        0.664039 -0.810812 -0.677328 -0.689782  0.440278 -0.554916
# AM        0.599832 -0.522607 -0.589928 -0.227285  0.712711 -0.692495
# Gear      0.480285 -0.492687 -0.530916 -0.091671  0.699610 -0.583287
# Carb     -0.550925  0.526988  0.407567  0.761158 -0.090790  0.427606
#
#               Qsec        VS        AM      Gear      Carb
# MPG       0.418684  0.664039  0.599832  0.480285 -0.550925
# Cylinder -0.591242 -0.810812 -0.522607 -0.492687  0.526988
# Disp     -0.428585 -0.677328 -0.589928 -0.530916  0.407567
# HP       -0.711671 -0.689782 -0.227285 -0.091671  0.761158
# Drat      0.091205  0.440278  0.712711  0.699610 -0.090790
# Wt       -0.174716 -0.554916 -0.692495 -0.583287  0.427606
# Qsec      1.000000  0.744535 -0.229861 -0.212682 -0.656249
# VS        0.744535  1.000000  0.168345  0.206023 -0.569607
# AM       -0.229861  0.168345  1.000000  0.794059  0.057534
# Gear     -0.212682  0.206023  0.794059  1.000000  0.274073
# Carb     -0.656249 -0.569607  0.057534  0.274073  1.000000

# %%
from scipy import stats

sb.distplot(cars.HP)
print("Range of Skewness, S < |1.96|")

print("Skewness of hp: ",stats.skew(cars.HP))
print("Skewness of wt: ",stats.skew(cars.Wt))


print("Kurtosis of hp: ",stats.kurtosis(cars.HP))
print("Kurtosis of wt: ",stats.kurtosis(cars.Wt))

#both HP and Wt passing normality test, they are normal values coming between the range of -1.96 to + 1.96
# Out:
# Range of Skewness, S < |1.96|
# Skewness of hp:  0.8444142994364577
# Skewness of wt:  0.44378553550607736
# Kurtosis of hp:  0.2424939159880557
# Kurtosis of wt:  0.1724705401587343

# %% [markdown]
# ### Build Model

# %%
X = cars.loc[:,['HP','Wt','AM']]
y = cars.MPG

# %%
# training and testing model selection
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.20,random_state=100)

# %%
print("X_train shape", X_train.shape)
print("X_test shape", X_test.shape)
print("y_train shape", y_train.shape)
print("y_test shape", y_test.shape)
# Out:
# X_train shape (25, 3)
# X_test shape (7, 3)
# y_train shape (25,)
# y_test shape (7,)

# %%
# Importing machine learning algorithm
from sklearn.linear_model import LinearRegression

# %% [markdown]
# help(LinearRegression)

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_predict = model.predict(X_test)

# %%
y_predict=list(y_predict)

# %%
y_test=list(y_test)

# %%
X_test
# Out:
#             HP     Wt  AM
# 13  145.206897  3.780   0
# 28  264.000000  3.170   1
# 1   110.000000  2.875   1
# 26   91.000000  2.140   1
# 5   105.000000  3.460   0
# 18   52.000000  1.615   1
# 29  175.000000  2.770   1

# %%
pd.DataFrame([y_predict,y_test])
# Out:
#            0          1          2          3          4         5         6
# 0  17.833426  17.946496  24.466699  27.143853  20.187091  30.00215  22.32991
# 1  15.200000  15.800000  21.000000  26.000000  18.100000  30.40000  19.70000

# %%
# Model evaluation 
from sklearn.metrics import r2_score, accuracy_score
from sklearn import metrics

# %%
r2_score(y_test,y_predict)
# Out:
# 0.8027724896732761

# %%
plt.scatter(y_test,y_predict)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 2.072189385508344
# MSE: 5.185634503149621
# RMSE: 2.2771988281987197

# %% [raw]
# In the above model we have not done any data cleaning and preprocessing hence we got a bad score.
#
# now, lets do some data cleaning and do the training and prediction.

# %% [markdown]
# # Data Cleaning

# %%
#Outlier analsis
cars.HP.plot(kind="box")

# %%
cars[cars.HP==cars.HP.max()]
# Out:
#            Model    MPG  Cylinder   Disp     HP  Drat    Wt  Qsec  VS  AM  \
# 30  Maserati Bora  15.0         8  301.0  335.0  3.54  3.57  14.6   0   1
#
#     Gear  Carb
# 30     5     8

# %%
cars_final = cars.drop(index=30)

# %%
cars_final
# Out:
#                  Model    MPG  Cylinder        Disp          HP  Drat     Wt  \
# 0             Mazda RX4  21.0         6  160.000000  110.000000  3.90  2.620
# 1         Mazda RX4 Wag  21.0         6  160.000000  110.000000  3.90  2.875
# 2            Datsun 710  22.8         4  108.000000   93.000000  3.85  2.320
# 3        Hornet 4 Drive  21.4         6  258.000000  110.000000  3.08  3.215
# 4     Hornet Sportabout  18.7         8  360.000000  175.000000  3.15  3.440
# 5               Valiant  18.1         6  225.000000  105.000000  2.76  3.460
# 6            Duster 360  14.3         8  360.000000  245.000000  3.21  3.570
# 7             Merc 240D  24.4         4  146.700000   62.000000  3.69  3.190
# 8              Merc 230  22.8         4  140.800000   95.000000  3.92  3.150
# 9              Merc 280  19.2         6  229.789655  145.206897  3.92  3.440
# 10            Merc 280C  17.8         6  167.600000  123.000000  3.92  3.440
# 11           Merc 450SE  16.4         8  229.789655  180.000000  3.07  4.070
# 12           Merc 450SL  17.3         8  229.789655  145.206897  3.07  3.730
# 13          Merc 450SLC  15.2         8  275.800000  145.206897  3.07  3.780
# 14   Cadillac Fleetwood  10.4         8  472.000000  205.000000  2.93  5.250
# 15  Lincoln Continental  10.4         8  460.000000  215.000000  3.00  5.424
# 16    Chrysler Imperial  14.7         8  440.000000  230.000000  3.23  5.345
# 17             Fiat 128  32.4         4   78.700000   66.000000  4.08  2.200
# 18          Honda Civic  30.4         4   75.700000   52.000000  4.93  1.615
# 19       Toyota Corolla  33.9         4   71.100000   65.000000  4.22  1.835
# 20        Toyota Corona  21.5         4  120.100000   97.000000  3.70  2.465
# 21     Dodge Challenger  15.5         8  318.000000  150.000000  2.76  3.520
# 22          AMC Javelin  15.2         8  304.000000  150.000000  3.15  3.435
# 23           Camaro Z28  13.3         8  350.000000  245.000000  3.73  3.840
# 24     Pontiac Firebird  19.2         8  400.000000  175.000000  3.08  3.845
# 25            Fiat X1-9  27.3         4   79.000000   66.000000  4.08  1.935
# 26        Porsche 914-2  26.0         4  120.300000   91.000000  4.43  2.140
# 27         Lotus Europa  30.4         4   95.100000  113.000000  3.77  1.513
# 28       Ford Pantera L  15.8         8  351.000000  264.000000  4.22  3.170
# 29         Ferrari Dino  19.7         6  145.000000  175.000000  3.62  2.770
# 31           Volvo 142E  21.4         4  121.000000  109.000000  4.11  2.780
#
#      Qsec  VS  AM  Gear  Carb
# 0   16.46   0   1     4     4
# 1   17.02   0   1     4     4
# 2   18.61   1   1     4     1
# 3   19.44   1   0     3     1
# 4   17.02   0   0     3     2
# 5   20.22   1   0     3     1
# 6   15.84   0   0     3     4
# 7   20.00   1   0     4     2
# 8   22.90   1   0     4     2
# 9   18.30   1   0     4     4
# 10  18.90   1   0     4     4
# 11  17.40   0   0     3     3
# 12  17.60   0   0     3     3
# 13  18.00   0   0     3     3
# 14  17.98   0   0     3     4
# 15  17.82   0   0     3     4
# 16  17.42   0   0     3     4
# 17  19.47   1   1     4     1
# 18  18.52   1   1     4     2
# 19  19.90   1   1     4     1
# 20  20.01   1   0     3     1
# 21  16.87   0   0     3     2
# 22  17.30   0   0     3     2
# 23  15.41   0   0     3     4
# 24  17.05   0   0     3     2
# 25  18.90   1   1     4     1
# 26  16.70   0   1     5     2
# 27  16.90   1   1     5     2
# 28  14.50   0   1     5     4
# 29  15.50   0   1     5     6
# 31  18.60   1   1     4     2

# %%
X = cars_final.loc[:,['HP','Wt','AM']]
y = cars_final.MPG
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20,random_state=14)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-f51578d873dd> in <module>()
# ----> 1 X = cars_final.loc[:,['HP','Wt','AM']]
#       2 y = cars_final.MPG
#       3 X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20,random_state=14)
#
# NameError: name 'cars_final' is not defined

# %%
model_lr = LinearRegression()
model_lr.fit(X_train,y_train)
y_predict = model_lr.predict(X_test)
r2_score(y_test,y_predict)
# Out:
# 0.9422574039646744

# %%
y_test
# Out:
# 2     22.8
# 18    30.4
# 15    10.4
# 3     21.4
# 26    26.0
# Name: MPG, dtype: float64

# %%
y_predict
# Out:
# array([26.166262  , 29.86396788, 10.08696523, 20.66543271, 26.74673071])

# %%
# print the intercept
print(model_lr.intercept_)
# Out:
# 34.22279657053797

# %%
predictions = model_lr.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
# Model evaluation 
from sklearn.metrics import r2_score, accuracy_score
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 1.1393253788462094
# MSE: 2.562847382431891
# RMSE: 1.6008895597235593

# %%
sb.regplot(x = "HP", y = "MPG", data = cars)
