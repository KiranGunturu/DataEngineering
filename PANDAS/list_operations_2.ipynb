# %%
ListA=[1,2,3,4]

# %%
ListB=ListA

# %%
print(ListB)
# Out:
# ['X', 2, 3, 4]

# %%
ListB[0]='X'

# %%
print(ListA)
# Out:
# ['X', 2, 3, 4]

# %%
tmp1=[1,2,3,3,9,10]

# %%
tmp2=[4,2,1,5,7]

# %%
list(set(tmp1)-set(tmp2))
# Out:
# [9, 10, 3]

# %%
list(set(tmp2)-set(tmp1))
# Out:
# [4, 5, 7]

# %%
list(set(tmp1+tmp2))
# Out:
# [1, 2, 3, 4, 5, 7, 9, 10]

# %%
len(tmp2)
# Out:
# 5

# %%
print(list(set(tmp1)))
# Out:
# [1, 2, 3, 9, 10]

# %%
for i in tmp1:
    tmp2.append(i)

# %%
tmp1
# Out:
# [1, 2, 3, 3, 9, 10]

# %%
tmp2
# Out:
# [4, 2, 1, 5, 7, 1, 2, 3, 3, 9, 10]

# %%
res_list = [y for x in [tmp1, tmp2] for y in x]

# %%
res_list
# Out:
# [1, 2, 3, 3, 9, 10, 4, 2, 1, 5, 7, 1, 2, 3, 3, 9, 10]

# %%
res_list.sort(reverse=False)

# %%
print(list(set(res_list)))
# Out:
# [1, 2, 3, 4, 5, 7, 9, 10]
