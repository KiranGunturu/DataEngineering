# %%
n=int(input("enter your number : "))
count=0
while count<=11:
    print(n,"x",count,"=",n*count)
    count+=1
# Out:
# enter your number : 2
# 2 x 0 = 0
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
# 2 x 11 = 22

# %%
names=list()

# %%
type(names)
# Out:
# list

# %%
age=[]

# %%
type(age)
# Out:
# list

# %%
names=list()

# %%
names.append(10,11,12,13,13,14)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-9b55fdf39ff5> in <module>
# ----> 1 names.append(10,11,12,13,13,14)
#
# TypeError: append() takes exactly one argument (6 given)

# %%
names
# Out:
# [10]

# %%
names.append(11)

# %%
names
# Out:
# [10, 11]

# %%
names.append(11)

# %%
names
# Out:
# [10, 11, 11]

# %%
names[0]
# Out:
# 10

# %%
names[2]
# Out:
# 11

# %%
names[::-1]
# Out:
# [11, 11, 10]

# %%
names=list(set(names))

# %%
names
# Out:
# {10, 11}

# %%
names
# Out:
# [10, 11]

# %%
names.append(12)

# %%
names.append(14)

# %%
names
# Out:
# [10, 11, 12, 14]

# %%
names[0],names[3] = names[3],names[0]

# %%
names
# Out:
# [14, 11, 12, 10]

# %%
max(names)
# Out:
# 14

# %%
min(names)
# Out:
# 10

# %%
names.pop() # pop will always removes the last value from the list
# Out:
# 10

# %%
names
# Out:
# [14, 11, 12]

# %%
names.pop(1)
# Out:
# 11

# %%
names
# Out:
# [14, 12]

# %%
names
# Out:
# [14, 12]

# %%
names.remove(14) # remove will remove the value bases where as pop is bases of index

# %%
names
# Out:
# [12]

# %%
names
# Out:
# [12]

# %%
names.append(13)

# %%
names.append(12)

# %%
names
# Out:
# [12, 13, 12]

# %%
names.remove(12) # if there are multiple values then remove will remove the value with lower index

# %%
names
# Out:
# [13, 12]

# %%
names
# Out:
# [13, 12]

# %%
total = 0
for i in range(len(names)):
    total+=names[i]
print(total)
# Out:
# 25

# %%
#list: []
#mutable(can be chnaged like append,pop amd remove)
#can have duplicates
# following operations can be done : append, remove and pop, search
# can hold diff datatype values
#tuple: ()
#immutable
# can have dupes
# can hold diff datatype values
# following operations can be done : initialize , search

# %%
tuple=("Kiran","Hello","Hello",11,12,True)

# %%
tuple
# Out:
# ('Kiran', 'Hello')

# %%
tuple
# Out:
# ('Kiran', 'Hello', 'Hello')

# %%
tuple
# Out:
# ('Kiran', 'Hello', 'Hello')

# %%
tuple
# Out:
# ('Kiran', 'Hello', 'Hello', 11, 12, True)

# %%
names
# Out:
# [13, 12]

# %%
12 in names
# Out:
# True

# %%
13 in names
# Out:
# True

# %%
tuple
# Out:
# ('Kiran', 'Hello', 'Hello', 11, 12, True)

# %%
11 in tuple
# Out:
# True

# %%
14 in tuple
# Out:
# False

# %%
tuple[0]
# Out:
# 'Kiran'

# %%
tuple(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-8b627870aa58> in <module>
# ----> 1 tuple(0)
#
# TypeError: 'tuple' object is not callable

# %%
tuple.index('Kiran') # silicing
# Out:
# 0

# %%
tuple(1:3)
# Out:
#   File "<ipython-input-68-f016abfb8fe5>", line 1
#     tuple(1:3)
#            ^
# SyntaxError: invalid syntax

# %%
tuple[1:] # indexing - pos and neg. in pos : 0,1,2, ---n in neg index : -n ... -3 -2 -1
# Out:
# ('Hello', 'Hello', 11, 12, True)

# %%
tuple[-1]
# Out:
# True

# %%
tuple
# Out:
# ('Kiran', 'Hello', 'Hello', 11, 12, True)

# %%
tuple[-2]
# Out:
# 12

# %%
names
# Out:
# [13, 12]

# %%
names[-1]
# Out:
# 12

# %%
names[-2]
# Out:
# 13

# %%
tuple
# Out:
# ('Kiran', 'Hello', 'Hello', 11, 12, True)

# %%
tuple[-2:] # print last two values
# Out:
# (12, True)

# %%
tuple
# Out:
# ('Kiran', 'Hello', 'Hello', 11, 12, True)

# %%
tuple[1:5]
# Out:
# ('Hello', 'Hello', 11, 12)

# %%
dict={}

# %%
type(dict)
# Out:
# dict

# %%
age=dict()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-cef2c5c5b1ff> in <module>
# ----> 1 age=dict()
#
# TypeError: 'dict' object is not callable

# %%
age=dict{}
# Out:
#   File "<ipython-input-83-91f39372521a>", line 1
#     age=dict{}
#             ^
# SyntaxError: invalid syntax

# %%
dict={"fruits": ['banana','apple','orange'],"price":[10,20,30]}

# %%
dict
# Out:
# {'fruits': ['banana', 'apple', 'orange'], 'price': [10, 20, 30]}

# %%
dict.values()
# Out:
# dict_values([['banana', 'apple', 'orange'], [10, 20, 30]])

# %%
dict.keys()
# Out:
# dict_keys(['fruits', 'price'])

# %%
dict={"fruits":['banana','apple','orange'],"price":[1,25,40]}

# %%
dict
# Out:
# {'fruits': ['banana', 'apple', 'orange'], 'price': [1, 25, 40]}

# %%
dict["fruits"].append("mango")

# %%
dict
# Out:
# {'fruits': ['banana', 'apple', 'orange', 'mango'], 'price': [1, 25, 40]}

# %%
dict["price"].append(45)

# %%
dict
# Out:
# {'fruits': ['banana', 'apple', 'orange', 'mango'], 'price': [1, 25, 40, 45]}

# %%
dict["season"] = ['winter','summer']

# %%
dict
# Out:
# {'fruits': ['banana', 'apple', 'orange', 'mango'],
#  'price': [1, 25, 40, 45],
#  'season': ['winter', 'summer']}

# %%
dict["season"].append["summer"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-0f659f2bbfd8> in <module>
# ----> 1 dict["season"].append["summer"]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
dict
# Out:
# {'fruits': ['banana', 'apple', 'orange', 'mango'],
#  'price': [1, 25, 40, 45],
#  'season': ['Monsoon']}

# %%
dict
# Out:
# {'fruits': ['banana', 'apple', 'orange', 'mango'],
#  'price': [1, 25, 40, 45],
#  'season': ['Monsoon']}

# %%
dict["season"].append("summer")

# %%
dict
# Out:
# {'fruits': ['banana', 'apple', 'orange', 'mango'],
#  'price': [1, 25, 40, 45],
#  'season': ['Monsoon', 'summer']}

# %%
dict["price"].append("46")

# %%
dict
# Out:
# {'fruits': ['banana', 'apple', 'orange', 'mango'],
#  'price': [1, 25, 40, 45, '46'],
#  'season': ['Monsoon', 'summer']}

# %%
dict2={'fruits':'mango','price':100}

# %%
dict2
# Out:
# {'fruits': 'mango', 'price': 100}

# %%
dict2["fruits"]="Apple"

# %%
dict2
# Out:
# {'fruits': 'Apple', 'price': 100}

# %%
dict2["fruits"].append("mango")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-116-667ac49d7899> in <module>
# ----> 1 dict2["fruits"].append("mango")
#
# AttributeError: 'str' object has no attribute 'append'

# %%
n=4
for row in range(n):
    print("*")
# Out:
# *
# *
# *
# *

# %%
a=10

# %%
a
# Out:
# 10

# %%
for row in range(4):
    for col in range(row+1):
        print("# ",end="")
    print("\n")
# Out:
# #
#
# # #
#
# # # #
#
# # # # #

# %%
for row in range(4):
    for col in range(4):
        print("# ",end="")
    print("\n")
# Out:
# # # # #
#
# # # # #
#
# # # # #
#
# # # # #

# %%
for row in range(4):
    for col in range(4-row):
        print("# ",end="")
    print("\n")
# Out:
# # # # #
#
# # # #
#
# # #
#
# #

# %%
row=0
for col in range(4-row):
    print("# ",end="")
print("\n")
# Out:
# # # # #

# %%
row=1
for col in range(4-row):
    print("# ",end="")
print("\n")
# Out:
# # # #

# %%
row=2
for col in range(4-row):
    print("# ",end="")
print("\n")
# Out:
# # #

# %%
row=3
for col in range(4-row):
    print("# ",end="")
print("\n")
# Out:
# #

# %%
row=0
for col in range(row+1):
    print("# ",end="")
print("\n")
# Out:
# #

# %%
row=1
for col in range(row+1):
    print("# ",end="")
print("\n")
# Out:
# # #

# %%
row=2
for col in range(row+1):
    print("# ",end="")
print("\n")
# Out:
# # # #

# %%
row=3
for col in range(row+1):
    print("# ",end="")
print("\n")
# Out:
# # # # #

# %%
for row in range(4):
    print(row+1,end="")
print("\n")
# Out:
# 1234

# %%
for row in range(4):
    for col in range(4-row):
        print(col+row+1,end=" ")
    print("\n")
# Out:
# 1 2 3 4
#
# 2 3 4
#
# 3 4
#
# 4

# %%
row=0
for col in range(4-row):
    print(col+1,end="")
print("\n")
# Out:
# 1234

# %%
row=1
for col in range(4-row):
    print(col+1,end="")
print("\n")
# Out:
# 123

# %%
row=0
for col in range(4-row):
    print(col+1,end="")
print("\n")
# Out:
# 1234

# %%
row=1
for col in range(4-row):
    print(col+2,end="")
print("\n")
# Out:
# 234

# %%
row=2
for col in range(4-row):
    print(col+2,end="")
print("\n")
# Out:
# 23

# %%
for row in range(5):
    for col in range(row+1):
        print("# ",end="")
    print("\n")
for row in range(4):
    for col in range(4-row):
        print("# ",end="")
    print("\n")
# Out:
# #
#
# # #
#
# # # #
#
# # # # #
#
# # # # # #
#
# # # # #
#
# # # #
#
# # #
#
# #

# %%
number=int(input("enter the number pattern:"))
for row in range(number):
    for col in range(row):
        print("# ",end="")
    print("\n")
# Out:
# enter the number pattern:5
#
#
# #
#
# # #
#
# # # #
#
# # # # #

# %%
number=int(input("enter the number pattern:"))
for row in range(number-1):
    for col in range(number-row):
        print("# ",end="")
    print("\n")
# Out:
# enter the number pattern:5
# # # # # #
#
# # # # #
#
# # # #
#
# # #

# %%
number=int(input("enter the number pattern:"))
for row in range(number):
    for col in range(row):
        print("# ",end="")
    print("\n")
#number=int(input("enter the number pattern:"))
for row in range(number-1):
    for col in range(number-row):
        print("# ",end="")
    print("\n")
# Out:
# enter the number pattern:5
#
#
# #
#
# # #
#
# # # #
#
# # # # #
#
# # # # # #
#
# # # # #
#
# # # #
#
# # #

# %%
number=int(input("enter no of rows: "))
for row in range(number):
    for col in range(number-row):
        print(col+row,end=" ")
    print("\n")
