# %%
import findspark
findspark.init()
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql.functions import *
spark=SparkSession.builder.appName("Test").getOrCreate()

# %%
employee= [
    (1,'scott',"Tiger",1000.0,10,True,"US"),
    (5,'sco',"Will",1250.0,10,True,"US"),
    (2,'James',"Micky",1250.0,None,True,"UK"),
    (3,'Mike',"Wilson",1400.0,'',False,"india"),
    (4,'Thomos',"George",1400.0,10,False,"AUS"),
    (6,'Tho',"Ge",1500.0,10,False,None)
]

# %%
df1=spark.createDataFrame(employee,schema="id int, fname string, lname string, salary float, bonus string, is_customer string,nation string")

# %%
df1.show()
# Out:
# +---+------+------+------+-----+-----------+------+
# | id| fname| lname|salary|bonus|is_customer|nation|
# +---+------+------+------+-----+-----------+------+
# |  1| scott| Tiger|1000.0|   10|       true|    US|
# |  5|   sco|  Will|1250.0|   10|       true|    US|
# |  2| James| Micky|1250.0| null|       true|    UK|
# |  3|  Mike|Wilson|1400.0|     |      false| india|
# |  4|Thomos|George|1400.0|   10|      false|   AUS|
# |  6|   Tho|    Ge|1500.0|   10|      false|  null|
# +---+------+------+------+-----+-----------+------+

# %%
df1.filter(col('id')==2).show()
# Out:
# +---+-----+-----+------+-----+-----------+------+
# | id|fname|lname|salary|bonus|is_customer|nation|
# +---+-----+-----+------+-----+-----------+------+
# |  2|James|Micky|1250.0| null|       true|    UK|
# +---+-----+-----+------+-----+-----------+------+

# %%
df1.filter(col('id')>2).count()
# Out:
# 2

# %%
df1.filter("id ==2").show()
# Out:
# +---+-----+-----+------+-----+-----------+------+
# | id|fname|lname|salary|bonus|is_customer|nation|
# +---+-----+-----+------+-----+-----------+------+
# |  2|James|Micky|1250.0| null|       true|    UK|
# +---+-----+-----+------+-----+-----------+------+

# %%
df1.filter(df1['id']==2).show()
# Out:
# +---+-----+-----+------+-----+-----------+------+
# | id|fname|lname|salary|bonus|is_customer|nation|
# +---+-----+-----+------+-----+-----------+------+
# |  2|James|Micky|1250.0| null|       true|    UK|
# +---+-----+-----+------+-----+-----------+------+

# %% [markdown]
# # Equal -> = or ==
# # Not Equal -> !=
# # Greater than -> >
# # Less than -> <
# # Greater than equal to -> >=
# # Less than equal to -> <=
# # IN operator -> isin function or IN or contains function
#
# # Between operator -> between function or BETWEEN with AND

# %%
df1.filter(col('is_customer')== True).show()
# Out:
# +---+-----+-----+------+-----+-----------+------+
# | id|fname|lname|salary|bonus|is_customer|nation|
# +---+-----+-----+------+-----+-----------+------+
# |  1|scott|Tiger|1000.0|   10|       true|    US|
# |  2|James|Micky|1250.0| null|       true|    UK|
# +---+-----+-----+------+-----+-----------+------+

# %%
df1.filter(col('is_customer')=='True').show()
# Out:
# +---+-----+-----+------+-----+-----------+------+
# | id|fname|lname|salary|bonus|is_customer|nation|
# +---+-----+-----+------+-----+-----------+------+
# +---+-----+-----+------+-----+-----------+------+

# %%
df1.filter('is_customer == true').show()
# Out:
# +---+-----+-----+------+-----+-----------+------+
# | id|fname|lname|salary|bonus|is_customer|nation|
# +---+-----+-----+------+-----+-----------+------+
# |  1|scott|Tiger|1000.0|   10|       true|    US|
# |  2|James|Micky|1250.0| null|       true|    UK|
# +---+-----+-----+------+-----+-----------+------+

# %%
df1.filter(col('is_customer')==False).show()
# Out:
# +---+------+------+------+-----+-----------+------+
# | id| fname| lname|salary|bonus|is_customer|nation|
# +---+------+------+------+-----+-----------+------+
# |  3|  Mike|Wilson|1350.0|     |      false| india|
# |  4|Thomos|George|1400.0|   10|      false|   AUS|
# +---+------+------+------+-----+-----------+------+

# %%
df1.createOrReplaceTempView("users")

# %%
spark.sql("select *from users where is_customer='true'").show()
# Out:
# +---+-----+-----+------+-----+-----------+------+
# | id|fname|lname|salary|bonus|is_customer|nation|
# +---+-----+-----+------+-----+-----------+------+
# |  1|scott|Tiger|1000.0|   10|       true|    US|
# |  2|James|Micky|1250.0| null|       true|    UK|
# +---+-----+-----+------+-----+-----------+------+

# %%
#f1.filter(col('salary')=='1000.0').show()
df1.filter(col('salary')==1000.0).show()
# Out:
# +---+-----+-----+------+-----+-----------+------+
# | id|fname|lname|salary|bonus|is_customer|nation|
# +---+-----+-----+------+-----+-----------+------+
# |  1|scott|Tiger|1000.0|   10|       true|    US|
# +---+-----+-----+------+-----+-----------+------+

# %%
#df1.filter((df1.nation=='US') & (df1.salary==1000.0)).show()
df1.filter((df1.nation=='US') & (df1.salary==1000.0)).show()
# Out:
# +---+-----+-----+------+-----+-----------+------+
# | id|fname|lname|salary|bonus|is_customer|nation|
# +---+-----+-----+------+-----+-----------+------+
# |  1|scott|Tiger|1000.0|   10|       true|    US|
# +---+-----+-----+------+-----+-----------+------+

# %%
df1.show()
# Out:
# +---+------+------+------+-----+-----------+------+
# | id| fname| lname|salary|bonus|is_customer|nation|
# +---+------+------+------+-----+-----------+------+
# |  1| scott| Tiger|1000.0|   10|       true|    US|
# |  5|   sco|  Will|1250.0|   10|       true|    US|
# |  2| James| Micky|1250.0| null|       true|    UK|
# |  3|  Mike|Wilson|1400.0|     |      false| india|
# |  4|Thomos|George|1400.0|   10|      false|   AUS|
# +---+------+------+------+-----+-----------+------+

# %%
df1.filter(col('nation')!='US').show()
# Out:
# +---+------+------+------+-----+-----------+------+
# | id| fname| lname|salary|bonus|is_customer|nation|
# +---+------+------+------+-----+-----------+------+
# |  2| James| Micky|1250.0| null|       true|    UK|
# |  3|  Mike|Wilson|1400.0|     |      false| india|
# |  4|Thomos|George|1400.0|   10|      false|   AUS|
# +---+------+------+------+-----+-----------+------+

# %%
df1.show()
# Out:
# +---+------+------+------+-----+-----------+------+
# | id| fname| lname|salary|bonus|is_customer|nation|
# +---+------+------+------+-----+-----------+------+
# |  1| scott| Tiger|1000.0|   10|       true|    US|
# |  5|   sco|  Will|1250.0|   10|       true|    US|
# |  2| James| Micky|1250.0| null|       true|    UK|
# |  3|  Mike|Wilson|1400.0|     |      false| india|
# |  4|Thomos|George|1400.0|   10|      false|   AUS|
# +---+------+------+------+-----+-----------+------+

# %%
df1.select('id','nation').\
filter(col('nation')!='US').show()
# Out:
# +---+------+
# | id|nation|
# +---+------+
# |  2|    UK|
# |  3| india|
# |  4|   AUS|
# +---+------+

# %%
#df1.filter((col('nation')=='US') & (col('salary')==1000.0)).show()
df1.filter((df1.nation=='US') & (df1.salary==1000.0)).show()
# Out:
# +---+-----+-----+------+-----+-----------+------+
# | id|fname|lname|salary|bonus|is_customer|nation|
# +---+-----+-----+------+-----+-----------+------+
# |  1|scott|Tiger|1000.0|   10|       true|    US|
# +---+-----+-----+------+-----+-----------+------+

# %%
df1.show()
# Out:
# +---+------+------+------+-----+-----------+------+
# | id| fname| lname|salary|bonus|is_customer|nation|
# +---+------+------+------+-----+-----------+------+
# |  1| scott| Tiger|1000.0|   10|       true|    US|
# |  5|   sco|  Will|1250.0|   10|       true|    US|
# |  2| James| Micky|1250.0| null|       true|    UK|
# |  3|  Mike|Wilson|1400.0|     |      false| india|
# |  4|Thomos|George|1400.0|   10|      false|   AUS|
# |  6|   Tho|    Ge|1500.0|   10|      false|  null|
# +---+------+------+------+-----+-----------+------+

# %%
df1.filter(col('nation')!='US').show() # if nulls are there in nation column those will not be displayed
# Out:
# +---+------+------+------+-----+-----------+------+
# | id| fname| lname|salary|bonus|is_customer|nation|
# +---+------+------+------+-----+-----------+------+
# |  2| James| Micky|1250.0| null|       true|    UK|
# |  3|  Mike|Wilson|1400.0|     |      false| india|
# |  4|Thomos|George|1400.0|   10|      false|   AUS|
# +---+------+------+------+-----+-----------+------+

# %%
df1.filter((col('nation')!='US') | (col('nation').isNull())).show()
# Out:
# +---+------+------+------+-----+-----------+------+
# | id| fname| lname|salary|bonus|is_customer|nation|
# +---+------+------+------+-----+-----------+------+
# |  2| James| Micky|1250.0| null|       true|    UK|
# |  3|  Mike|Wilson|1400.0|     |      false| india|
# |  4|Thomos|George|1400.0|   10|      false|   AUS|
# |  6|   Tho|    Ge|1500.0|   10|      false|  null|
# +---+------+------+------+-----+-----------+------+

# %%
df1.show()
# Out:
# +---+------+------+------+-----+-----------+------+
# | id| fname| lname|salary|bonus|is_customer|nation|
# +---+------+------+------+-----+-----------+------+
# |  1| scott| Tiger|1000.0|   10|       true|    US|
# |  5|   sco|  Will|1250.0|   10|       true|    US|
# |  2| James| Micky|1250.0| null|       true|    UK|
# |  3|  Mike|Wilson|1400.0|     |      false| india|
# |  4|Thomos|George|1400.0|   10|      false|   AUS|
# |  6|   Tho|    Ge|1500.0|   10|      false|  null|
# +---+------+------+------+-----+-----------+------+

# %%
from pyspark.sql.functions import *

# %%
df1.filter((col('id').between(1,4)) & (col('nation')=='US')).show()
# Out:
# +---+-----+-----+------+-----+-----------+------+
# | id|fname|lname|salary|bonus|is_customer|nation|
# +---+-----+-----+------+-----+-----------+------+
# |  1|scott|Tiger|1000.0|   10|       true|    US|
# +---+-----+-----+------+-----+-----------+------+

# %%
df1.filter(col('id').between(1,4)).show()
# Out:
# +---+------+------+------+-----+-----------+------+
# | id| fname| lname|salary|bonus|is_customer|nation|
# +---+------+------+------+-----+-----------+------+
# |  1| scott| Tiger|1000.0|   10|       true|    US|
# |  2| James| Micky|1250.0| null|       true|    UK|
# |  3|  Mike|Wilson|1400.0|     |      false| india|
# |  4|Thomos|George|1400.0|   10|      false|   AUS|
# +---+------+------+------+-----+-----------+------+

# %%
df1.show()
# Out:
# +---+------+------+------+-----+-----------+------+
# | id| fname| lname|salary|bonus|is_customer|nation|
# +---+------+------+------+-----+-----------+------+
# |  1| scott| Tiger|1000.0|   10|       true|    US|
# |  5|   sco|  Will|1250.0|   10|       true|    US|
# |  2| James| Micky|1250.0| null|       true|    UK|
# |  3|  Mike|Wilson|1400.0|     |      false| india|
# |  4|Thomos|George|1400.0|   10|      false|   AUS|
# |  6|   Tho|    Ge|1500.0|   10|      false|  null|
# +---+------+------+------+-----+-----------+------+

# %%
df1.filter(col('bonus').isNull()).show()
# Out:
# +---+-----+-----+------+-----+-----------+------+
# | id|fname|lname|salary|bonus|is_customer|nation|
# +---+-----+-----+------+-----+-----------+------+
# |  2|James|Micky|1250.0| null|       true|    UK|
# +---+-----+-----+------+-----+-----------+------+

# %%
df1.filter(col('bonus').isNotNull()).show()
# Out:
# +---+------+------+------+-----+-----------+------+
# | id| fname| lname|salary|bonus|is_customer|nation|
# +---+------+------+------+-----+-----------+------+
# |  1| scott| Tiger|1000.0|   10|       true|    US|
# |  5|   sco|  Will|1250.0|   10|       true|    US|
# |  3|  Mike|Wilson|1400.0|     |      false| india|
# |  4|Thomos|George|1400.0|   10|      false|   AUS|
# |  6|   Tho|    Ge|1500.0|   10|      false|  null|
# +---+------+------+------+-----+-----------+------+

# %% [markdown]
# # Boolean OR - if any one condition is True then the statement will return True

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %% [markdown]
# # Boolean AND - If any one False then the statement will return False

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %% [markdown]
# # Negate

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
df1.show()
# Out:
# +---+------+------+------+-----+-----------+------+
# | id| fname| lname|salary|bonus|is_customer|nation|
# +---+------+------+------+-----+-----------+------+
# |  1| scott| Tiger|1000.0|   10|       true|    US|
# |  5|   sco|  Will|1250.0|   10|       true|    US|
# |  2| James| Micky|1250.0| null|       true|    UK|
# |  3|  Mike|Wilson|1400.0|     |      false| india|
# |  4|Thomos|George|1400.0|   10|      false|   AUS|
# |  6|   Tho|    Ge|1500.0|   10|      false|  null|
# +---+------+------+------+-----+-----------+------+

# %%
df1.filter(col('nation').isin('US','india')).show()
# Out:
# +---+-----+------+------+-----+-----------+------+
# | id|fname| lname|salary|bonus|is_customer|nation|
# +---+-----+------+------+-----+-----------+------+
# |  1|scott| Tiger|1000.0|   10|       true|    US|
# |  5|  sco|  Will|1250.0|   10|       true|    US|
# |  3| Mike|Wilson|1400.0|     |      false| india|
# +---+-----+------+------+-----+-----------+------+
