# %%
import findspark
findspark.init()
import pyspark
from pyspark.sql import SparkSession
spark=SparkSession.builder.getOrCreate()
#df=spark.read.csv("Downloads/flight-time.csv").option("header","true")
df=spark.read.format("csv").option("header","true").load("/users/kirangunturu/Downloads/flight-time.csv")

# %%
# https://www.planetofbits.com/python/change-jupyter-notebook-startup-folder-anaconda/

# %%
df.count()
# Out:
# 470477

# %%
df.head()
# Out:
# Row(FL_DATE='1/1/2000', OP_CARRIER='DL', OP_CARRIER_FL_NUM='1451', ORIGIN='BOS', ORIGIN_CITY_NAME='Boston, MA', DEST='ATL', DEST_CITY_NAME='Atlanta, GA', CRS_DEP_TIME='1115', DEP_TIME='1113', WHEELS_ON='1343', TAXI_IN='5', CRS_ARR_TIME='1400', ARR_TIME='1348', CANCELLED='0', DISTANCE='946')

# %%
df.show()
# Out:
# +--------+----------+-----------------+------+----------------+----+--------------+------------+--------+---------+-------+------------+--------+---------+--------+
# | FL_DATE|OP_CARRIER|OP_CARRIER_FL_NUM|ORIGIN|ORIGIN_CITY_NAME|DEST|DEST_CITY_NAME|CRS_DEP_TIME|DEP_TIME|WHEELS_ON|TAXI_IN|CRS_ARR_TIME|ARR_TIME|CANCELLED|DISTANCE|
# +--------+----------+-----------------+------+----------------+----+--------------+------------+--------+---------+-------+------------+--------+---------+--------+
# |1/1/2000|        DL|             1451|   BOS|      Boston, MA| ATL|   Atlanta, GA|        1115|    1113|     1343|      5|        1400|    1348|        0|     946|
# |1/1/2000|        DL|             1479|   BOS|      Boston, MA| ATL|   Atlanta, GA|        1315|    1311|     1536|      7|        1559|    1543|        0|     946|
# ...

# %%
df.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3c9a60fd698f> in <module>
# ----> 1 df.count()
#
# NameError: name 'df' is not defined

# %%
df.count()
# Out:
# 470477
