# %%
emp = {'name':['Kiran','Krish','John'],'gender':['male','male','male'],'email':['abc@gmail.com','def@gmail.com','ghi@gmail.com']}

# %%
emp
# Out:
# {'name': ['Kiran', 'Krish', 'John'],
#  'gender': ['male', 'male', 'male'],
#  'email': ['abc@gmail.com', 'def@gmail.com', 'ghi@gmail.com']}

# %%
import pandas as pd

# %%
df = pd.DataFrame(emp)

# %%
df
# Out:
#     name gender          email
# 0  Kiran   male  abc@gmail.com
# 1  Krish   male  def@gmail.com
# 2   John   male  ghi@gmail.com

# %%
fc = (df['name']=='Kiran')

# %%
df.index = [0,1,2]

# %%
df[fc]
# Out:
#     name gender          email
# 0  Kiran   male  abc@gmail.com
# 1  Kiran   male  def@gmail.com
# 2  Kiran   male  ghi@gmail.com

# %%
df
# Out:
#     name gender          email
# 0  Kiran   male  abc@gmail.com
# 1  Kiran   male  def@gmail.com
# 2  Kiran   male  ghi@gmail.com

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
#alter the index
df.index = ['a','b','c']

# %%
df
# Out:
#     name gender          email
# a  Kiran   male  abc@gmail.com
# b  Kiran   male  def@gmail.com
# c  Kiran   male  ghi@gmail.com

# %%
df.columns
# Out:
# Index(['name', 'gender', 'email'], dtype='object')

# %%
#rename all columns
df.columns = ['emp_name','gender','emp_email']

# %%
df
# Out:
#   emp_name gender      emp_email
# 0    Kiran   male  abc@gmail.com
# 1    Kiran   male  def@gmail.com
# 2    Kiran   male  ghi@gmail.com

# %%
#rename specific column names
df.rename(columns = {'emp_name':'name','emp_email':'email_id'},inplace=True)

# %%
df
# Out:
#     name gender       email_id
# 0  Kiran   male  abc@gmail.com
# 1  Kiran   male  def@gmail.com
# 2  Kiran   male  ghi@gmail.com

# %%
# update a full row
df.loc[0] = ['Emily','Female','emily@gmail.com']

# %%
df
# Out:
#     name  gender         email_id
# 0  Emily  Female  emily@gmail.com
# 1  Kiran    male    def@gmail.com
# 2  Kiran    male    ghi@gmail.com

# %%
# update value of one row
df.loc[0,'name'] = 'John'

# %%
df
# Out:
#     name  gender         email_id
# 0   John  Female  emily@gmail.com
# 1  Kiran    male    def@gmail.com
# 2  Kiran    male    ghi@gmail.com

# %%
#update value of two rows
df.loc[0,['name','email_id']] = ['Michael','Michael@gmail.com']

# %%
del df['email']

# %%
df
# Out:
#       name  gender           email_id
# 0  Michael  Female  Michael@gmail.com
# 1    Kiran    male      def@gmail.com
# 2    Kiran    male      ghi@gmail.com

# %%
df['name'].apply(len)
# Out:
# 0    7
# 1    5
# 2    5
# Name: name, dtype: int64

# %%
df['gender'].apply(len)
# Out:
# 0    6
# 1    4
# 2    4
# Name: gender, dtype: int64

# %%
def update_email(email_id):
    return email_id.upper()

# %%
#apply udf to only specific column
df['email_id'] = df['email_id'].apply(update_email)

# %%
df
# Out:
#       name  gender           email_id
# 0  Michael  Female  MICHAEL@GMAIL.COM
# 1    Kiran    male      DEF@GMAIL.COM
# 2    Kiran    male      GHI@GMAIL.COM

# %%
# apply udf to all columns
df.applymap(update_email)
# Out:
#       name  gender           email_id
# 0  MICHAEL  FEMALE  MICHAEL@GMAIL.COM
# 1    KIRAN    MALE      DEF@GMAIL.COM
# 2    KIRAN    MALE      GHI@GMAIL.COM

# %%
# apply - to a series
# applymap - to multiple serieses (dataframe)

# %%
#apply string functions directly on series objects like columns
df['name'] = df['name'].str.upper()

# %%
df
# Out:
#       name  gender           email_id
# 0  MICHAEL  Female  MICHAEL@GMAIL.COM
# 1    KIRAN    male      DEF@GMAIL.COM
# 2    KIRAN    male      GHI@GMAIL.COM

# %%
df['gender'] = df['gender'].str.upper()

# %%
df
# Out:
#       name  gender           email_id
# 0  MICHAEL  FEMALE  MICHAEL@GMAIL.COM
# 1    KIRAN    MALE      DEF@GMAIL.COM
# 2    KIRAN    MALE      GHI@GMAIL.COM

# %%
df
# Out:
#       name  gender           email_id
# 0  MICHAEL    True  MICHAEL@GMAIL.COM
# 1    KIRAN    True      DEF@GMAIL.COM
# 2    KIRAN    True      GHI@GMAIL.COM

# %%
df
# Out:
#       name  gender           email_id
# 0  MICHAEL    True  MICHAEL@GMAIL.COM
# 1    KIRAN    True      DEF@GMAIL.COM
# 2    KIRAN    True      GHI@GMAIL.COM

# %%
emp = {'name':['Kiran','Krish','John'],'gender':['male','male','male'],'email':['abc@gmail.com','def@gmail.com','ghi@gmail.com']}

# %%
df=pd.DataFrame(emp)
df
# Out:
#     name gender          email
# 0  Kiran   male  abc@gmail.com
# 1  Krish   male  def@gmail.com
# 2   John   male  ghi@gmail.com

# %%
# add a new column
df['salary'] = 10000

# %%
df
# Out:
#     name gender          email  salary
# 0  Kiran   male  abc@gmail.com   10000
# 1  Krish   male  def@gmail.com   10000
# 2   John   male  ghi@gmail.com   10000

# %%
df['name_gender'] = df['name'] + ' ' +  df['gender']

# %%
df
# Out:
#     name gender          email  salary name_gender
# 0  Kiran   male  abc@gmail.com   10000  Kiran male
# 1  Krish   male  def@gmail.com   10000  Krish male
# 2   John   male  ghi@gmail.com   10000   John male

# %%
# update salary to emp whose name = 'Kiran'
fc = (df['name']=='Kiran')
df.loc[fc,'salary']=5000

# %%
df
# Out:
#     name gender          email  salary name_gender
# 0  Kiran   male  abc@gmail.com    5000  Kiran male
# 1  Krish   male  def@gmail.com   10000  Krish male
# 2   John   male  ghi@gmail.com   10000   John male

# %%
# ddelete rows
df.drop(index=0)
# Out:
#     name gender          email  salary name_gender
# 1  Krish   male  def@gmail.com   10000  Krish male
# 2   John   male  ghi@gmail.com   10000   John male

# %%
df
# Out:
#     name gender          email  salary name_gender
# 0  Kiran   male  abc@gmail.com    5000  Kiran male
# 1  Krish   male  def@gmail.com   10000  Krish male
# 2   John   male  ghi@gmail.com   10000   John male

# %%
#df.drop(index=0,inplace=True)

# %%
df
# Out:
#     name gender          email  salary name_gender
# 0  Kiran   male  abc@gmail.com    5000  Kiran male
# 1  Krish   male  def@gmail.com   10000  Krish male
# 2   John   male  ghi@gmail.com   10000   John male

# %%
fc=(df['salary']>5000)
fc
# Out:
# 0    False
# 1     True
# 2     True
# Name: salary, dtype: bool

# %%
df.drop(index=df[fc].index)
# Out:
#     name gender          email  salary name_gender
# 0  Kiran   male  abc@gmail.com    5000  Kiran male

# %%
# drop a column
df.drop(columns='name_gender')
# Out:
#     name gender          email  salary
# 0  Kiran   male  abc@gmail.com    5000
# 1  Krish   male  def@gmail.com   10000
# 2   John   male  ghi@gmail.com   10000

# %%
#sorting asc
df.sort_values(by='name')
# Out:
#     name gender          email  salary name_gender
# 2   John   male  ghi@gmail.com   10000   John male
# 0  Kiran   male  abc@gmail.com    5000  Kiran male
# 1  Krish   male  def@gmail.com   10000  Krish male

# %%
#sorting desc
df.sort_values(by='salary',ascending=False)
# Out:
#     name gender          email  salary name_gender
# 1  Krish   male  def@gmail.com   10000  Krish male
# 2   John   male  ghi@gmail.com   10000   John male
# 0  Kiran   male  abc@gmail.com    5000  Kiran male

# %%
#sort based on two columns
df.sort_values(by=['gender','salary'])
# Out:
#     name gender          email  salary name_gender
# 0  Kiran   male  abc@gmail.com    5000  Kiran male
# 1  Krish   male  def@gmail.com   10000  Krish male
# 2   John   male  ghi@gmail.com   10000   John male

# %%
df.sort_values(by=['gender','salary'],ascending=[False,True])
# Out:
#     name gender          email  salary name_gender
# 0  Kiran   male  abc@gmail.com    5000  Kiran male
# 1  Krish   male  def@gmail.com   10000  Krish male
# 2   John   male  ghi@gmail.com   10000   John male

# %%
df.sort_index()
# Out:
#     name gender          email  salary name_gender
# 0  Kiran   male  abc@gmail.com    5000  Kiran male
# 1  Krish   male  def@gmail.com   10000  Krish male
# 2   John   male  ghi@gmail.com   10000   John male

# %%
df.sort_index(ascending=False)
# Out:
#     name gender          email  salary name_gender
# 2   John   male  ghi@gmail.com   10000   John male
# 1  Krish   male  def@gmail.com   10000  Krish male
# 0  Kiran   male  abc@gmail.com    5000  Kiran male
